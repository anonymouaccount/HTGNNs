# %% [markdown]
# <a href="https://colab.research.google.com/github/raniaabidi/HTGNNs/blob/main/HTGNN_houses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['LC_ALL'] = 'en_US.UTF-8'

# %%
import pandas as pd
import numpy as np
import networkx as nx
from sklearn.model_selection import train_test_split

# Load the dataset
ratings = pd.read_csv('/content/drive/MyDrive/user_activity.csv')

# Convert timestamp to datetime
ratings['timestamp'] = pd.to_datetime(ratings['create_timestamp'])

# Sort by timestamp
ratings = ratings.sort_values(by='timestamp')

# Split the data into train and test sets
train_data, test_data = train_test_split(ratings, test_size=0.2, shuffle=False)

# Create graph structures with numeric timestamps
def create_graph(data):
    G = nx.DiGraph()
    for _, row in data.iterrows():
        # Use the timestamp() method to get a numeric timestamp
        G.add_edge(row['user_id'], row['item_id'], timestamp=row['timestamp'].timestamp())
    return G

train_graph = create_graph(train_data)
test_graph = create_graph(test_data)

# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.5.3-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.13.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.10.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.3.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.7.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.5.0)
# Downloading torch_geometric-2.5.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.1 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.5.3

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data, DataLoader

# Convert NetworkX graph to PyTorch Geometric Data object
def convert_to_pyg_data(graph, num_features=8):
    nodes = list(graph.nodes())
    node_mapping = {node: i for i, node in enumerate(nodes)}
    edge_index = torch.tensor([[node_mapping[u], node_mapping[v]] for u, v in graph.edges]).t().contiguous()
    edge_time = torch.tensor([graph[u][v]['timestamp'] for u, v in graph.edges], dtype=torch.float)

    # Create a feature matrix with fixed number of features per node
    x = torch.randn(len(nodes), num_features)

    # Random labels for the nodes (binary classification: 0 or 1)
    y = torch.randint(0, 2, (len(nodes),))

    data = Data(x=x, edge_index=edge_index, edge_time=edge_time, y=y)
    return data

train_data_pyg = convert_to_pyg_data(train_graph)
test_data_pyg = convert_to_pyg_data(test_graph)

train_loader = DataLoader([train_data_pyg], batch_size=1, shuffle=True)
test_loader = DataLoader([test_data_pyg], batch_size=1, shuffle=False)

class HTGNN(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(HTGNN, self).__init__()
        self.conv1 = GCNConv(in_channels, 8)
        self.conv2 = GCNConv(8 + 8, out_channels)
        self.time_embedding = torch.nn.Embedding(365, 8)

    def forward(self, x, edge_index, edge_time):
        print(f'Input x shape: {x.shape}')
        print(f'Edge index shape: {edge_index.shape}')
        print(f'Edge time shape: {edge_time.shape}')

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        print(f'x after conv1 shape: {x.shape}')

        # Embedding for the edge times
        time_embeds = self.time_embedding((edge_time.long() % 365).view(-1, 1)).view(-1, 8)
        print(f'time_embeds shape: {time_embeds.shape}')

        # Average the edge time embeddings per node
        node_time_embeds = torch.zeros_like(x)
        for i in range(edge_index.size(1)):
            node_time_embeds[edge_index[0, i]] += time_embeds[i]
        print(f'node_time_embeds shape: {node_time_embeds.shape}')

        x = torch.cat([x, node_time_embeds], dim=1)
        print(f'x after concatenation shape: {x.shape}')

        x = self.conv2(x, edge_index)
        print(f'x after conv2 shape: {x.shape}')

        return x

# Initialize the model, loss function, and optimizer
model = HTGNN(in_channels=train_data_pyg.num_node_features, out_channels=2)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = torch.nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
# Training function
def train(model, loader, optimizer, loss_fn):
    model.train()
    total_loss = 0
    for data in loader:
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.edge_time)
        loss = loss_fn(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

# Evaluation function
def evaluate(model, loader):
    model.eval()
    correct = 0
    for data in loader:
        out = model(data.x, data.edge_index, data.edge_time)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

# Training loop
for epoch in range(100):
    train_loss = train(model, train_loader, optimizer, loss_fn)
    test_acc = evaluate(model, test_loader)
    print(f'Epoch {epoch}, Loss: {train_loss}, Test Accuracy: {test_acc}')
# Out:
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 0, Loss: 5.174750328063965, Test Accuracy: 2284.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 1, Loss: 4.329800605773926, Test Accuracy: 2295.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 2, Loss: 3.925978899002075, Test Accuracy: 2304.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 3, Loss: 3.7638792991638184, Test Accuracy: 2301.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 4, Loss: 3.513345241546631, Test Accuracy: 2300.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 5, Loss: 3.169739246368408, Test Accuracy: 2294.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 6, Loss: 2.825671434402466, Test Accuracy: 2289.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 7, Loss: 2.5746700763702393, Test Accuracy: 2290.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 8, Loss: 2.466481924057007, Test Accuracy: 2282.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 9, Loss: 2.3820793628692627, Test Accuracy: 2273.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 10, Loss: 2.2327535152435303, Test Accuracy: 2280.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 11, Loss: 2.0386133193969727, Test Accuracy: 2273.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 12, Loss: 1.8478833436965942, Test Accuracy: 2285.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 13, Loss: 1.6972099542617798, Test Accuracy: 2293.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 14, Loss: 1.5859142541885376, Test Accuracy: 2288.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 15, Loss: 1.4913396835327148, Test Accuracy: 2274.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 16, Loss: 1.3980355262756348, Test Accuracy: 2277.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 17, Loss: 1.2868704795837402, Test Accuracy: 2281.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 18, Loss: 1.1653765439987183, Test Accuracy: 2289.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 19, Loss: 1.0530848503112793, Test Accuracy: 2298.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 20, Loss: 0.9627130627632141, Test Accuracy: 2306.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 21, Loss: 0.8940184116363525, Test Accuracy: 2313.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 22, Loss: 0.8428781032562256, Test Accuracy: 2309.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 23, Loss: 0.8049180507659912, Test Accuracy: 2338.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 24, Loss: 0.8017715215682983, Test Accuracy: 2331.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 25, Loss: 0.8202123641967773, Test Accuracy: 2325.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 26, Loss: 0.8400416374206543, Test Accuracy: 2332.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 27, Loss: 0.8474533557891846, Test Accuracy: 2348.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 28, Loss: 0.845453679561615, Test Accuracy: 2327.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 29, Loss: 0.8508257865905762, Test Accuracy: 2324.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 30, Loss: 0.8676389455795288, Test Accuracy: 2331.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 31, Loss: 0.8792598247528076, Test Accuracy: 2341.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 32, Loss: 0.8751251697540283, Test Accuracy: 2347.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 33, Loss: 0.8587480783462524, Test Accuracy: 2341.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 34, Loss: 0.8414912819862366, Test Accuracy: 2342.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 35, Loss: 0.8291831612586975, Test Accuracy: 2345.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 36, Loss: 0.8147351145744324, Test Accuracy: 2343.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 37, Loss: 0.7935606837272644, Test Accuracy: 2336.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 38, Loss: 0.7688403129577637, Test Accuracy: 2336.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 39, Loss: 0.7439765334129333, Test Accuracy: 2331.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 40, Loss: 0.7243059277534485, Test Accuracy: 2312.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 41, Loss: 0.7134440541267395, Test Accuracy: 2282.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 42, Loss: 0.7077774405479431, Test Accuracy: 2280.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 43, Loss: 0.7071937918663025, Test Accuracy: 2278.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 44, Loss: 0.7174440622329712, Test Accuracy: 2283.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 45, Loss: 0.7304246425628662, Test Accuracy: 2275.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 46, Loss: 0.7365577220916748, Test Accuracy: 2273.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 47, Loss: 0.7373002767562866, Test Accuracy: 2279.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 48, Loss: 0.736257016658783, Test Accuracy: 2286.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 49, Loss: 0.7329444289207458, Test Accuracy: 2278.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 50, Loss: 0.7261855602264404, Test Accuracy: 2272.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 51, Loss: 0.7171185612678528, Test Accuracy: 2300.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 52, Loss: 0.7088124752044678, Test Accuracy: 2306.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 53, Loss: 0.7037306427955627, Test Accuracy: 2308.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 54, Loss: 0.7003785371780396, Test Accuracy: 2349.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 55, Loss: 0.6973744034767151, Test Accuracy: 2344.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 56, Loss: 0.6976600289344788, Test Accuracy: 2364.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 57, Loss: 0.7014997005462646, Test Accuracy: 2356.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 58, Loss: 0.7044243216514587, Test Accuracy: 2331.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 59, Loss: 0.7053049802780151, Test Accuracy: 2334.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 60, Loss: 0.7055195569992065, Test Accuracy: 2339.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 61, Loss: 0.7050186395645142, Test Accuracy: 2343.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 62, Loss: 0.7033572196960449, Test Accuracy: 2345.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 63, Loss: 0.700844943523407, Test Accuracy: 2335.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# ...
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 78, Loss: 0.6939396262168884, Test Accuracy: 2354.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 79, Loss: 0.6941927075386047, Test Accuracy: 2340.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 80, Loss: 0.694463849067688, Test Accuracy: 2337.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 81, Loss: 0.6946935653686523, Test Accuracy: 2346.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 82, Loss: 0.6948957443237305, Test Accuracy: 2346.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 83, Loss: 0.6948222517967224, Test Accuracy: 2344.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 84, Loss: 0.6944514513015747, Test Accuracy: 2345.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 85, Loss: 0.6941503882408142, Test Accuracy: 2347.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 86, Loss: 0.693908154964447, Test Accuracy: 2335.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 87, Loss: 0.693700909614563, Test Accuracy: 2295.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 88, Loss: 0.6936355829238892, Test Accuracy: 2303.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 89, Loss: 0.6936831474304199, Test Accuracy: 2306.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 90, Loss: 0.693723738193512, Test Accuracy: 2334.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 91, Loss: 0.6937367916107178, Test Accuracy: 2336.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 92, Loss: 0.6937928795814514, Test Accuracy: 2336.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 93, Loss: 0.6937761902809143, Test Accuracy: 2337.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 94, Loss: 0.6936802268028259, Test Accuracy: 2329.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 95, Loss: 0.6935871243476868, Test Accuracy: 2322.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 96, Loss: 0.6934972405433655, Test Accuracy: 2333.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 97, Loss: 0.693423330783844, Test Accuracy: 2341.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 98, Loss: 0.6933857798576355, Test Accuracy: 2351.0
# Input x shape: torch.Size([26267, 8])
# Edge index shape: torch.Size([2, 227623])
# Edge time shape: torch.Size([227623])
# x after conv1 shape: torch.Size([26267, 8])
# time_embeds shape: torch.Size([227623, 8])
# node_time_embeds shape: torch.Size([26267, 8])
# x after concatenation shape: torch.Size([26267, 16])
# x after conv2 shape: torch.Size([26267, 2])
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Epoch 99, Loss: 0.6933800578117371, Test Accuracy: 2365.0

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.preprocessing import label_binarize

# Function to calculate MRR
def mrr_score(y_true, y_pred):
    order = np.argsort(y_pred)[::-1]
    ranks = np.where(y_true[order] == 1)[0] + 1
    return np.mean(1.0 / ranks)

# Function to calculate NDCG
def ndcg_score(y_true, y_pred, k=10):
    order = np.argsort(y_pred)[::-1]
    y_true = np.take(y_true, order[:k])

    gains = 2 ** y_true - 1
    discounts = np.log2(np.arange(2, k + 2))
    dcg = np.sum(gains / discounts)

    ideal_gains = 2 ** np.sort(y_true)[::-1] - 1
    idcg = np.sum(ideal_gains / discounts)

    return dcg / idcg if idcg > 0 else 0.0

# Evaluation function with metrics
def evaluate_with_metrics(model, loader):
    model.eval()
    all_preds = []
    all_labels = []
    for data in loader:
        out = model(data.x, data.edge_index, data.edge_time)
        pred = out.argmax(dim=1)
        all_preds.append(pred.detach().cpu().numpy())
        all_labels.append(data.y.detach().cpu().numpy())

    all_preds = np.concatenate(all_preds)
    all_labels = np.concatenate(all_labels)

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    mrr = mrr_score(all_labels, all_preds)
    ndcg = ndcg_score(all_labels, all_preds)

    return accuracy, precision, recall, f1, mrr, ndcg

# Function to calculate just the accuracy
def calculate_accuracy(model, loader):
    model.eval()
    correct = 0
    total = 0
    for data in loader:
        out = model(data.x, data.edge_index, data.edge_time)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
        total += data.y.size(0)
    accuracy = correct / total
    return accuracy

accuracy, precision, recall, f1, mrr, ndcg = evaluate_with_metrics(model, test_loader)
print(f' NDCG: {ndcg}, Precision: {precision}, Recall: {recall}, F1-Score: {f1}')

accuracy = calculate_accuracy(model, test_loader)
print(f'Final Accuracy: {accuracy}')
# Out:
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
#  NDCG: 0.8670945531783741, Precision: 0.5098989263727594, Recall: 0.5092809730861908, F1-Score: 0.5025917538922132
# Input x shape: torch.Size([4619, 8])
# Edge index shape: torch.Size([2, 60938])
# Edge time shape: torch.Size([60938])
# x after conv1 shape: torch.Size([4619, 8])
# time_embeds shape: torch.Size([60938, 8])
# node_time_embeds shape: torch.Size([4619, 8])
# x after concatenation shape: torch.Size([4619, 16])
# x after conv2 shape: torch.Size([4619, 2])
# Final Accuracy: 0.5115825936349859

# %%
import numpy as np
from scipy.stats import norm

random_accuracy = 0.5
n = len(test_loader.dataset)

se = np.sqrt(random_accuracy * (1 - random_accuracy) / n)

z_score = (accuracy - random_accuracy) / se

p_value = 2 * norm.sf(np.abs(z_score))

print(f"P-value: {p_value}")
